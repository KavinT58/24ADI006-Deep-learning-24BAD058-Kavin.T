# %%
print("24BAD058 Kavin.T")
import numpy as np
import matplotlib.pyplot as plt
print("Part-A")

x = np.linspace(-10, 10, 400)

sigmoid = 1 / (1 + np.exp(-x))
tanh = np.tanh(x)
relu = np.maximum(0, x)

plt.figure(figsize=(10, 8))

plt.subplot(3, 1, 1)
plt.plot(x, sigmoid)
plt.title("Sigmoid Activation Function")
plt.xlabel("Input")
plt.ylabel("Output")
plt.grid()

plt.subplot(3, 1, 2)
plt.plot(x, tanh)
plt.title("Tanh Activation Function")
plt.xlabel("Input")
plt.ylabel("Output")
plt.grid()

plt.subplot(3, 1, 3)
plt.plot(x, relu)
plt.title("ReLU Activation Function")
plt.xlabel("Input")
plt.ylabel("Output")
plt.grid()

plt.tight_layout()
plt.show()
# Out:
# 24BAD058 Kavin.T
# Part-A

# %%
print("Part-B")
print("24BAD058 Kavin T")
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0

print("Training data shape:", x_train.shape)
print("Testing data shape:", x_test.shape)
# Out:
# Part-B
# 24BAD058 Kavin T
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Training data shape: (60000, 28, 28)
# Testing data shape: (10000, 28, 28)

# %%
def create_model(activation):
    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(28, 28)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(128, activation=activation),
        tf.keras.layers.Dense(64, activation=activation),
        tf.keras.layers.Dense(10, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %%
model_sigmoid = create_model('sigmoid')

history_sigmoid = model_sigmoid.fit(
    x_train,
    y_train,
    epochs=10,
    batch_size=128,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8065 - loss: 0.8780 - val_accuracy: 0.9054 - val_loss: 0.3632
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9153 - loss: 0.3064 - val_accuracy: 0.9307 - val_loss: 0.2447
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9345 - loss: 0.2289 - val_accuracy: 0.9433 - val_loss: 0.1987
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9473 - loss: 0.1839 - val_accuracy: 0.9532 - val_loss: 0.1699
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9556 - loss: 0.1527 - val_accuracy: 0.9566 - val_loss: 0.1523
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9630 - loss: 0.1283 - val_accuracy: 0.9616 - val_loss: 0.1369
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9681 - loss: 0.1097 - val_accuracy: 0.9632 - val_loss: 0.1262
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9732 - loss: 0.0943 - val_accuracy: 0.9667 - val_loss: 0.1154
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9765 - loss: 0.0826 - val_accuracy: 0.9673 - val_loss: 0.1100
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9797 - loss: 0.0711 - val_accuracy: 0.9704 - val_loss: 0.1020

# %%
model_tanh = create_model('tanh')

history_tanh = model_tanh.fit(
    x_train,
    y_train,
    epochs=10,
    batch_size=128,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8911 - loss: 0.3864 - val_accuracy: 0.9373 - val_loss: 0.2167
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9453 - loss: 0.1838 - val_accuracy: 0.9558 - val_loss: 0.1574
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9619 - loss: 0.1292 - val_accuracy: 0.9634 - val_loss: 0.1331
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9717 - loss: 0.0972 - val_accuracy: 0.9660 - val_loss: 0.1186
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9780 - loss: 0.0769 - val_accuracy: 0.9703 - val_loss: 0.1020
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9828 - loss: 0.0611 - val_accuracy: 0.9735 - val_loss: 0.0934
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9860 - loss: 0.0479 - val_accuracy: 0.9731 - val_loss: 0.0933
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9890 - loss: 0.0394 - val_accuracy: 0.9722 - val_loss: 0.0987
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9914 - loss: 0.0321 - val_accuracy: 0.9753 - val_loss: 0.0878
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9942 - loss: 0.0242 - val_accuracy: 0.9735 - val_loss: 0.0917

# %%
model_relu = create_model('relu')

history_relu = model_relu.fit(
    x_train,
    y_train,
    epochs=10,
    batch_size=128,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8938 - loss: 0.3768 - val_accuracy: 0.9464 - val_loss: 0.1860
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9560 - loss: 0.1507 - val_accuracy: 0.9645 - val_loss: 0.1277
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9690 - loss: 0.1056 - val_accuracy: 0.9658 - val_loss: 0.1149
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9759 - loss: 0.0813 - val_accuracy: 0.9687 - val_loss: 0.1035
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9804 - loss: 0.0642 - val_accuracy: 0.9667 - val_loss: 0.1064
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9834 - loss: 0.0529 - val_accuracy: 0.9725 - val_loss: 0.0980
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9867 - loss: 0.0439 - val_accuracy: 0.9714 - val_loss: 0.0925
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9904 - loss: 0.0343 - val_accuracy: 0.9736 - val_loss: 0.0928
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9911 - loss: 0.0290 - val_accuracy: 0.9752 - val_loss: 0.0935
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9933 - loss: 0.0238 - val_accuracy: 0.9747 - val_loss: 0.0944

# %%
results = pd.DataFrame({
    'Activation Function': ['Sigmoid', 'Tanh', 'ReLU'],
    'Training Accuracy': [
        history_sigmoid.history['accuracy'][-1],
        history_tanh.history['accuracy'][-1],
        history_relu.history['accuracy'][-1]
    ],
    'Validation Accuracy': [
        history_sigmoid.history['val_accuracy'][-1],
        history_tanh.history['val_accuracy'][-1],
        history_relu.history['val_accuracy'][-1]
    ],
    'Training Loss': [
        history_sigmoid.history['loss'][-1],
        history_tanh.history['loss'][-1],
        history_relu.history['loss'][-1]
    ],
    'Validation Loss': [
        history_sigmoid.history['val_loss'][-1],
        history_tanh.history['val_loss'][-1],
        history_relu.history['val_loss'][-1]
    ]
})

print(results)
# Out:
#   Activation Function  Training Accuracy  Validation Accuracy  Training Loss  \
# 0             Sigmoid           0.979729             0.970417       0.071106
# 1                Tanh           0.994229             0.973500       0.024204
# 2                ReLU           0.993312             0.974750       0.023755
#
#    Validation Loss
# 0         0.102028
# 1         0.091730
# 2         0.094391

# %%
plt.figure(figsize=(10, 6))

plt.plot(history_sigmoid.history['accuracy'], label='Sigmoid Training')
plt.plot(history_sigmoid.history['val_accuracy'], label='Sigmoid Validation')

plt.plot(history_tanh.history['accuracy'], label='Tanh Training')
plt.plot(history_tanh.history['val_accuracy'], label='Tanh Validation')

plt.plot(history_relu.history['accuracy'], label='ReLU Training')
plt.plot(history_relu.history['val_accuracy'], label='ReLU Validation')

plt.title('Training and Validation Accuracy Comparison')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(history_sigmoid.history['loss'], label='Sigmoid Training')
plt.plot(history_sigmoid.history['val_loss'], label='Sigmoid Validation')

plt.plot(history_tanh.history['loss'], label='Tanh Training')
plt.plot(history_tanh.history['val_loss'], label='Tanh Validation')

plt.plot(history_relu.history['loss'], label='ReLU Training')
plt.plot(history_relu.history['val_loss'], label='ReLU Validation')

plt.title('Training and Validation Loss Comparison')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# %%
print("Part-C")
print("24BAD058 Kavin.T")
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0

print("Training data shape:", x_train.shape)
print("Testing data shape:", x_test.shape)
# Out:
# Part-C
# 24BAD058 Kavin.T
# Training data shape: (60000, 28, 28)
# Testing data shape: (10000, 28, 28)

# %%
def create_model(optimizer):
    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(28, 28)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])

    model.compile(
        optimizer=optimizer,
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %%
optimizers = {
    'SGD': tf.keras.optimizers.SGD(learning_rate=0.01),
    'Momentum': tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9),
    'RMSProp': tf.keras.optimizers.RMSprop(learning_rate=0.001),
    'Adam': tf.keras.optimizers.Adam(learning_rate=0.001)
}

# %%
histories = {}

for name, optimizer in optimizers.items():
    print("Training with:", name)

    model = create_model(optimizer)

    history = model.fit(
        x_train,
        y_train,
        epochs=10,
        batch_size=128,
        validation_split=0.2,
        verbose=1
    )

    histories[name] = history
# Out:
# Training with: SGD
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6231 - loss: 1.4311 - val_accuracy: 0.8436 - val_loss: 0.7163
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8530 - loss: 0.5855 - val_accuracy: 0.8851 - val_loss: 0.4475
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8818 - loss: 0.4351 - val_accuracy: 0.9018 - val_loss: 0.3680
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8957 - loss: 0.3750 - val_accuracy: 0.9102 - val_loss: 0.3297
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9042 - loss: 0.3403 - val_accuracy: 0.9152 - val_loss: 0.3073
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9103 - loss: 0.3164 - val_accuracy: 0.9211 - val_loss: 0.2890
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9158 - loss: 0.2980 - val_accuracy: 0.9235 - val_loss: 0.2731
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9204 - loss: 0.2826 - val_accuracy: 0.9268 - val_loss: 0.2615
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9237 - loss: 0.2697 - val_accuracy: 0.9305 - val_loss: 0.2513
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9267 - loss: 0.2583 - val_accuracy: 0.9323 - val_loss: 0.2425
# Training with: Momentum
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8439 - loss: 0.5506 - val_accuracy: 0.9251 - val_loss: 0.2587
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9287 - loss: 0.2454 - val_accuracy: 0.9430 - val_loss: 0.2002
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9456 - loss: 0.1878 - val_accuracy: 0.9523 - val_loss: 0.1671
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9567 - loss: 0.1529 - val_accuracy: 0.9576 - val_loss: 0.1485
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9631 - loss: 0.1274 - val_accuracy: 0.9627 - val_loss: 0.1292
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9685 - loss: 0.1094 - val_accuracy: 0.9653 - val_loss: 0.1160
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9720 - loss: 0.0960 - val_accuracy: 0.9679 - val_loss: 0.1073
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9762 - loss: 0.0835 - val_accuracy: 0.9675 - val_loss: 0.1077
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9786 - loss: 0.0738 - val_accuracy: 0.9693 - val_loss: 0.1014
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9818 - loss: 0.0647 - val_accuracy: 0.9708 - val_loss: 0.0979
# Training with: RMSProp
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9002 - loss: 0.3508 - val_accuracy: 0.9476 - val_loss: 0.1822
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9556 - loss: 0.1517 - val_accuracy: 0.9601 - val_loss: 0.1341
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9691 - loss: 0.1042 - val_accuracy: 0.9692 - val_loss: 0.1083
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9767 - loss: 0.0780 - val_accuracy: 0.9693 - val_loss: 0.0975
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9811 - loss: 0.0614 - val_accuracy: 0.9736 - val_loss: 0.0891
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9852 - loss: 0.0499 - val_accuracy: 0.9732 - val_loss: 0.0962
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9875 - loss: 0.0401 - val_accuracy: 0.9762 - val_loss: 0.0862
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9892 - loss: 0.0340 - val_accuracy: 0.9761 - val_loss: 0.0880
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9918 - loss: 0.0272 - val_accuracy: 0.9759 - val_loss: 0.0925
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9928 - loss: 0.0230 - val_accuracy: 0.9763 - val_loss: 0.0975
# Training with: Adam
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8841 - loss: 0.4008 - val_accuracy: 0.9448 - val_loss: 0.1891
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9513 - loss: 0.1642 - val_accuracy: 0.9558 - val_loss: 0.1454
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9658 - loss: 0.1143 - val_accuracy: 0.9656 - val_loss: 0.1151
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9741 - loss: 0.0854 - val_accuracy: 0.9662 - val_loss: 0.1118
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9791 - loss: 0.0674 - val_accuracy: 0.9675 - val_loss: 0.1074
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9837 - loss: 0.0538 - val_accuracy: 0.9693 - val_loss: 0.1006
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9872 - loss: 0.0422 - val_accuracy: 0.9710 - val_loss: 0.1028
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9902 - loss: 0.0325 - val_accuracy: 0.9751 - val_loss: 0.0924
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9918 - loss: 0.0278 - val_accuracy: 0.9747 - val_loss: 0.0898
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9929 - loss: 0.0227 - val_accuracy: 0.9743 - val_loss: 0.0964

# %%
results = pd.DataFrame({
    'Optimizer': list(histories.keys()),
    'Training Loss': [
        histories[name].history['loss'][-1]
        for name in histories
    ],
    'Validation Loss': [
        histories[name].history['val_loss'][-1]
        for name in histories
    ],
    'Training Accuracy': [
        histories[name].history['accuracy'][-1]
        for name in histories
    ],
    'Validation Accuracy': [
        histories[name].history['val_accuracy'][-1]
        for name in histories
    ]
})

print(results)
# Out:
#   Optimizer  Training Loss  Validation Loss  Training Accuracy  \
# 0       SGD       0.258281         0.242504           0.926708
# 1  Momentum       0.064741         0.097941           0.981792
# 2   RMSProp       0.023025         0.097496           0.992833
# 3      Adam       0.022741         0.096394           0.992875
#
#    Validation Accuracy
# 0             0.932250
# 1             0.970833
# 2             0.976333
# 3             0.974333

# %%
plt.figure(figsize=(10, 6))

for name, history in histories.items():
    plt.plot(
        history.history['val_loss'],
        label=name
    )

plt.title('Validation Loss vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Validation Loss')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6))

for name, history in histories.items():
    plt.plot(
        history.history['val_accuracy'],
        label=name
    )

plt.title('Validation Accuracy vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Validation Accuracy')
plt.legend()
plt.grid()
plt.show()
